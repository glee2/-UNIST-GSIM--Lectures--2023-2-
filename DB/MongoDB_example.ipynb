# %%
import pymongo

# %%
# 데이터베이스 연결
connection = pymongo.MongoClient('localhost', 27017)
client = pymongo.MongoClient()
print(client)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
# DB 목록
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'uspto']

# %%
# Collection (테이블) 목록
client.uspto.list_collection_names()
# Out:
# ['citations', 'citations_mini', 'USPAT_mini', 'USPAT']

# %%
# USPAT collection에 저장된 document 출력
db = client["uspto"]
collection = db["USPAT"]
collection.find_one()
# Out:
# {'_id': ObjectId('640448527058e9b008e7c21b'),
#  'guid': 'US-11565042-B1',
#  'publicationReferenceDocumentNumber': '11565042',
#  'compositeId': '1000000383486!US-US-11565042',
#  'publicationReferenceDocumentNumber1': '11565042',
#  'datePublishedKwicHits': None,
#  'datePublished': '2023-01-31T00:00:00Z',
#  'inventionTitle': 'Anesthesia and/or sedation system and method',
#  'type': 'USPAT',
#  'mainClassificationCode': '1/1',
#  'applicantName': ['Bibian; Stéphane', 'Zikov; Tatjana', 'Barua; Sankar'],
#  'assigneeName': ['NeuroWave Systems Inc.'],
#  'uspcFullClassificationFlattened': None,
#  'ipcCodeFlattened': 'A61B5/369;A61M5/172;A61M5/142',
#  'cpcInventiveFlattened': 'A61M5/1723;A61B5/369',
#  'cpcAdditionalFlattened': 'A61M2005/14296;A61M2005/14208',
#  'applicationFilingDate': ['2013-08-08T00:00:00Z'],
#  'applicationFilingDateKwicHits': None,
#  'relatedApplFilingDate': ['2012-08-08T00:00:00Z'],
#  'primaryExaminer': 'Price; Nathan R',
#  'assistantExaminer': ['Frehe; William'],
#  'applicationNumber': '13/962565',
#  'frontPageStart': 1,
#  'frontPageEnd': 1,
#  'drawingsStart': 2,
#  'drawingsEnd': 57,
#  'specificationStart': 58,
#  'specificationEnd': 84,
#  'claimsStart': 84,
#  'claimsEnd': 85,
#  'abstractStart': 1,
#  'abstractEnd': 1,
#  'bibStart': 1,
#  'bibEnd': 1,
#  'certCorrectionStart': 0,
#  'certCorrectionEnd': 0,
#  'certReexaminationStart': 0,
#  'certReexaminationEnd': 0,
#  'supplementalStart': 0,
#  'supplementalEnd': 0,
#  'ptabStart': 0,
#  'ptabEnd': 0,
#  'amendStart': 0,
#  'amendEnd': 0,
#  'searchReportStart': 0,
#  'searchReportEnd': 0,
#  'pageCount': 85,
#  'pageCountDisplay': '85',
#  'previouslyViewed': False,
#  'unused': False,
#  'imageLocation': 'uspat/US/G42/650/115',
#  'imageFileName': '00000001.tif',
#  'cpcCodes': None,
#  'queryId': 27581344,
#  'tags': None,
#  'inventorsShort': 'Bibian; Stéphane et al.',
#  'familyIdentifierCur': 1000000383486,
#  'familyIdentifierCurStr': '1000000383486',
#  'languageIndicator': 'EN',
#  'databaseName': 'USPT',
#  'dwImageDoctypeList': None,
#  'dwImageLocList': None,
#  'dwPageCountList': None,
#  'dwImageDocidList': None,
#  'patentFamilyMembers': None,
#  'patentFamilyCountry': None,
#  'patentFamilySerialNumber': None,
#  'documentIdWithDashesDw': None,
#  'pfPublDate': None,
#  'pfPublDateKwicHits': None,
#  'priorityClaimsDate': None,
#  'priorityClaimsDateKwicHits': None,
#  'pfApplicationSerialNumber': None,
#  'pfApplicationDescriptor': None,
#  'pfLanguage': None,
#  'pfApplicationDate': None,
#  'pfApplicationDateKwicHits': None,
#  'clippedUri': None,
#  'source': None,
#  'documentId': '<span term="us11565042b1" class="highlight18">US 11565042 B1</span>',
#  'derwentAccessionNumber': None,
#  'documentSize': 260750,
#  'score': 0.0,
#  'governmentInterest': ['LICENSE RIGHTS-FEDERAL SPONSORED RESEARCH\n(1) The U.S. Government has a paid-up license in this invention and the right in limited circumstances to require the patent owner to license others on reasonable terms provided for by the terms of contract number W81XWH-11-C-0078 awarded by United States Army Medical Research Acquisition Activity (USAMRAA).'],
#  'kindCode': ['B1'],
#  'urpn': ['5741211',
#   '5786999',
#   '7438072',
#   '20020017296',
#   '20040193068',
#   '20060009733',
#   '20060009734',
#   '20110021978',
#   '20110130675',
#   '20120095433'],
#  'urpnCode': ['5741211',
#   '5786999',
#   '7438072',
#   '20020017296',
#   '20040193068',
#   '20060009733',
#   '20060009734',
#   '20110021978',
#   '20110130675',
#   '20120095433'],
#  'abstractedPatentNumber': None,
#  'assigneeCity': ['Cleveland'],
#  'assigneePostalCode': ['N/A'],
#  'assigneeState': ['OH'],
#  'assigneeTypeCode': ['02'],
#  'curIntlPatentClassificationPrimary': ['A61B5/369 20210101'],
#  'curIntlPatentClassificationPrimaryDateKwicHits': None,
#  'designatedStates': None,
#  'examinerGroup': '3783',
#  'issuedUsCrossRefClassification': None,
#  'jpoFtermCurrent': None,
#  'languageOfSpecification': None,
#  'chosenDrawingsReference': None,
#  'derwentClass': None,
#  'inventionTitleHighlights': None,
#  'cpcOrigInventiveClassificationHighlights': ['A61M5/1723 20130101',
#   'A61B5/369 20210101'],
#  'cpcInventiveDateKwicHits': None,
#  'cpcOrigAdditionalClassification': ['A61M2005/14208 20130101',
#   'A61M2005/14296 20130101'],
#  'cpcAdditionalDateKwicHits': None,
#  'curIntlPatentClssficationSecHighlights': None,
#  'fieldOfSearchClassSubclassHighlights': None,
#  'cpcCombinationSetsCurHighlights': None,
#  'applicantCountry': ['US', 'US', 'US'],
#  'applicantCity': ['Cleveland Heights', 'Cleveland Heights', 'Stow'],
#  'applicantState': ['OH', 'OH', 'OH'],
#  'applicantZipCode': ['N/A', 'N/A', 'N/A'],
#  'applicantAuthorityType': ['N/A', 'N/A', 'N/A'],
#  'applicantDescriptiveText': None,
#  'applicationSerialNumber': ['962565'],
#  'inventorCity': ['Cleveland Heights', 'Cleveland Heights', 'Stow'],
#  'inventorState': ['OH', 'OH', 'OH'],
#  'inventorPostalCode': ['N/A', 'N/A', 'N/A'],
#  'standardTitleTermsHighlights': None,
#  'primaryExaminerHighlights': 'Price; Nathan R',
#  'continuityData': ['us-provisional-application US 61680888 20120808'],
#  'inventors': None,
#  'uspcFullClassification': None,
#  'uspcCodeFmtFlattened': None,
#  'ipcCode': None,
#  'applicationNumberHighlights': ['13/962565'],
#  'dateProduced': '2023-01-11T00:00:00Z',
#  'auxFamilyMembersGroupTempPlaceHolder': None,
#  'priorityCountryCode': None,
#  'cpcCurAdditionalClassification': None,
#  'internationalClassificationMain': None,
#  'internationalClassificationSecondary': None,
#  'internationalClassificationInformational': None,
#  'europeanClassification': None,
#  'europeanClassificationMain': None,
#  'europeanClassificationSecondary': None,
#  'lanuageIndicator': None,
#  'intlPubClassificationPrimary': ['A61B5/0476 20060101 A61B005/0476'],
#  'intlPubClassificationPrimaryDateKwicHits': None,
#  'intlPubClassificationSecondary': ['A61M5/172 20060101 A61M005/172',
#   'A61B5/369 20210101 A61B005/369'],
#  'intlPubClassificationSecondaryDateKwicHits': None,
#  'publicationDate': None,
#  'derwentWeekInt': 0,
#  'derwentWeek': None,
#  'currentUsOriginalClassification': '1/1',
#  'currentUsCrossReferenceClassification': None,
#  'locarnoClassification': None,
#  'equivalentAbstractText': None,
#  'hagueIntlRegistrationNumber': None,
#  'hagueIntlFilingDate': None,
#  'hagueIntlFilingDateKwicHits': None,
#  'hagueIntlRegistrationDate': None,
#  'hagueIntlRegistrationDateKwicHits': None,
#  'hagueIntlRegistrationPubDate': None,
#  'hagueIntlRegistrationPubDateKwicHits': None,
#  'curIntlPatentClassificationNoninvention': ['A61M5/142 20060101'],
#  'curIntlPatentClassificationNoninventionDateKwicHits': None,
#  'curIntlPatentClassificationSecondary': ['A61M5/172 20060101'],
#  'curIntlPatentClassificationSecondaryDateKwicHits': None,
#  'abstractHtml': 'A system and method provides closed-loop sedation, anesthesia, or analgesia by monitoring EEG and automatically adjusting the delivery of sedative, anesthetic, and/or analgesic drugs to maintain that desired level of cortical activity for transportation or evacuation of the injured, and for closed-loop anesthesia during surgical care, and at all echelons of care.',
#  'descriptionHtml': 'BRIEF DESCRIPTION OF THE DRAWINGS<br />(1) <figref idref="DRAWINGS">FIG. <b>1</b>A</figref>. Depiction of a soldier applying the device having a separate monitor to an injured subject in the field.<br />(2) <figref idref="DRAWINGS">FIG. <b>1</b>B</figref>. Depiction of a soldier applying the device having an integrated monitor to an injured subject in the field.<br />(3) <figref idref="DRAWINGS">FIG. <b>2</b>A</figref>. Depiction of a responder applying the device having a separate monitor to an injured subject in a sports setting.<br />(4) <figref idref="DRAWINGS">FIG. <b>2</b>B</figref>. Depiction of a responder applying the device having an integrated monitor to an injured subject in a sports setting.<br />(5) <figref idref="DRAWINGS">FIG. <b>3</b>A</figref>. Close-up depiction of the device as applied to an injured subject\'s head with monitoring indicators on a separate monitor.<br />(6) <figref idref="DRAWINGS">FIG. <b>3</b>B</figref>. Close-up depiction of the device as applied to an injured subject\'s head with monitoring indicators on an integrated monitor.<br />(7) <figref idref="DRAWINGS">FIG. <b>4</b>A</figref>. Depiction of one embodiment of the flexible substrate with electrode array.<br />(8) <figref idref="DRAWINGS">FIG. <b>4</b>B</figref>. Depiction of another embodiment of the flexible substrate with electrode array, this one having semi-rigid comb structures used to help attach the electrode array to the subject\'s head in the presence of hair.<br />(9) <figref idref="DRAWINGS">FIG. <b>5</b>A</figref>. Depiction of an embodiment of the display portraying electrode signal quality and injured subject\'s brain activity with respect to potential presence or absence of seizure, consciousness or suppression.<br />(10) <figref idref="DRAWINGS">FIG. <b>5</b>B</figref>. Depiction of an embodiment of the display portraying electrode signal quality and injured subject\'s brain activity with respect to potential presence or absence of seizure, consciousness or suppression.<br />(11) <figref idref="DRAWINGS">FIG. <b>5</b>C</figref>. Depiction of an embodiment of the display portraying electrode signal quality and injured subject\'s brain activity with respect to potential presence or absence of seizure, consciousness or suppression.<br />(12) <figref idref="DRAWINGS">FIG. <b>5</b>D</figref>. Depiction of an embodiment of the display portraying electrode signal quality and injured subject\'s brain activity with respect to potential presence or absence of seizure, consciousness or suppression.<br />(13) <figref idref="DRAWINGS">FIG. <b>6</b></figref>. Graph showing the correlation between the WAV.sub.CNS index (an indicator of consciousness used by the present invention) and subject consciousness or level of sedation or anesthesia.<br />(14) <figref idref="DRAWINGS">FIG. <b>7</b></figref>. Block diagram of an application-specific integrated circuit (ASIC) utilized in some embodiments of the device.<br />(15) <figref idref="DRAWINGS">FIG. <b>8</b></figref>. System overview of one embodiment of the main processor for the disposable brain monitor (DBM).<br />(16) <figref idref="DRAWINGS">FIG. <b>9</b></figref>. Various views of one embodiment of the IMIS including A) front-left perspective view; B) front-right perspective view; C) back perspective view; D) front isometric view; (E) back isometric view; F) left isometric view; G) right isometric view; H) top isometric view; I) bottom isometric view; and J) isometric view.<br />(17) <figref idref="DRAWINGS">FIG. <b>10</b></figref>. Various screenshots of one embodiment of the present invention including: A) a screenshot of an “Effect” screen; B) a screenshot of a “Pumps” screen; C) another screenshot of a “Pumps” screen; D) a screenshot of a “PCLC” screen; E) another screenshot of a “PCLC” screen; F) another screenshot of a “Pumps” screen; G) a screenshot of a “patient information screen; and H) another screenshot of a “Patient information” screen.<br />(18 ...
#  'claimsHtml': "1. An apparatus for automated drug delivery of anesthesia or sedation to an unconscious subject comprising: at least two input channels for connecting with electroencephalogram (EEG) electrodes, having an EEG signal, the EEG electrodes for application to a subject's head; an interface adapted for entering the subject's weight and a predetermined index setpoint prior to administration of a drug for anesthesia or sedation to the subject; a processor comprising an algorithm for real-time monitoring of the subject's EEG signals, quantifying the EEG signals, and calculating a calculated index based on the subject's quantified EEG signals; at least one infusion pump or valve for delivery of the drug; wherein the at least one infusion pump or valve is adapted to be operated in a closed-loop, automatically and without human interaction to maintain the subject's unconsciousness at the predetermined index setpoint, and the at least one infusion pump or valve is adapted to be adjusted continuously with the processor to calculate a modification of an infusion rate of the drug to reach and/or maintain the predetermined index setpoint based on both the calculated index and the subject's weight, independent of the calculated index, once the apparatus has been applied to the subject, the subject's weight and the predetermined index setpoint have been entered by a user into the interface, and the apparatus thereafter has been set into the closed-loop.  <br /> 2. The apparatus in claim 1, wherein the algorithm is a first algorithm and the processor comprises a second algorithm, the first algorithm and the second algorithm separate from one another and configured to maintain the apparatus in the closed-loop control and that calculate an input of the at least one infusion pump or valve based on both a last available EEG signals, the first control algorithm having a first refresh rate and the second control algorithm having a second refresh rate that is slower than the first refresh rate of the first control algorithm; and wherein the at least one infusion pump or valve is further automatically operated in the closed-loop based on the calculated input of said first control algorithm when the EEG signal is available, and based on the calculated input of the said second control algorithm when the EEG signal is not available. <br /> 3. The apparatus in claim 1, further including a cortical suppression detection function on the processor adapted to monitor and notify the user when athe subject's brain function is suppressed below a threshold level. <br /> 4. The apparatus in claim 1, wherein the algorithm is a first algorithm and the processor comprises a second algorithm, the processor adapted to automatically switch between the first algorithm and the second algorithm based on the subject's reaction to the administration of the drug. <br /> 5. The apparatus in claim 1, wherein the processor is used in controlling the at least one infusion pump or valve through adaptive control. <br /> 6. The apparatus in claim 1, wherein the processor automatically adjusts in the closed-loop with no human intervention at least two infusion pumps and/or valves with one pump or valve to deliver either an anesthetic or sedative, and another to deliver an analgesic to the unconscious subject. <br /> 7. An apparatus for automated drug delivery of anesthesia or sedation and an analgesic to an unconscious subject comprising: an enclosure or modular system comprising at least two input channels for connecting with electroencephalogram (EEG) electrodes, having an EEG signal, the EEG electrodes for application to a subject's head; an interface adapted for entering the subject's weight and a predetermined index setpoint prior to administration of a drug for anesthesia or sedation to the subject; a processor comprising an algorithm for real-time monitoring of the subject's EEG signals, quantifying the EEG signals, and calculating a calculated index based on the  ...
#  'briefHtml': "BACKGROUND OF THE INVENTION<br />1. Field of the Invention<br />(1) The present invention relates to the monitoring and processing of signals, and particularly to the monitoring and processing of electrophysiological signals. More particularly, the present invention relates to processing electroencephalographic (EEG) signals to monitor brain function, detect the occurrence of traumatic brain injury (TBI). Even more particularly, the present invention relates to a system and method for screening, assessing, and providing mitigating treatment to improve the short- and long-term adverse outcomes of mild TBI (mTBI) and TBI. Further, the present invention relates to a system and method for providing a readily available tool to assist in the accurate and objective assessment of subjects with TBI, immediately at the point of injury (POI), during transportation, or upon arrival at a care facility, that is applicable without advanced training or expertise. Further still, the present invention relates to a system for providing closed-loop sedation for transportation or evacuation of the injured as well as closed-loop sedation or anesthesia at all echelons of care, including civilian care facilities.<br />2. Technical Background<br />(2) Traumatic brain injury (TBI) is the leading cause of death for military personnel and civilians under the age of 45 in the United States. It has been called the “signature wound” of the war in Iraq. More than 11,800 troops have been seriously injured in an improvised explosive device (IED) attack, and many thousands more have been near enough to the explosion to cause a concussion. Based on currently existing data, veterans' advocates believe that between 150,000 and 300,000 veterans suffer from some level of TBI. The rate of TBI rises to 33 percent among wounded troops.<br />(3) TBI is also a preeminent concern in the civilian population. According to the National Center for Injury Prevention and Control, over 1.4 million Americans sustain a TBI each year. Out of those 1.4 million, approximately 50,000 die, 235,000 are hospitalized, and almost 1.1 million are treated and released from an emergency department. The total direct and indirect cost of TBI among the civilian population was estimated to be about $60 billion in the United States in 2000. The major causes of such injuries among civilians include falls, motor vehicle accidents, struck by/against events, assaults, and blasts. Also, an estimated 1.6 million to 3.8 million sports-related TBIs occur each year.<br />(4) If left untreated, TBI can result in permanent brain damage, which in turn can lead to a variety of disabilities such as hemiplegia, amnesia, epilepsy, loss of speech, loss of hearing, loss of vision, increased risk of Alzheimer's and Parkinson's disease, sleep disorders/insomnia, etc. TBI can also result in long-term psychological problems such as Post Traumatic Stress Disorder (PTSD), attention deficit disorder (ADD), anxiety, and depression. Over 5 million Americans suffer from some sort of TBI-related disability and have a long-term need for help to perform normal day-to-day activities.<br />(5) Rapid recognition and diagnosis of the injury are paramount for the proper intervention and successful treatment of TBI. Unfortunately, TBI, and in particular mild TBI (mTBI), is difficult to detect and is considered to be vastly underdiagnosed. In addition, initial delays in diagnosis or misdiagnosis are exacerbated by environmental factors surrounding the injury, particularly in wartime and battle situations. Over 90 percent of combat-related TBIs are closed brain injuries. Soldiers who have unknowingly suffered a TBI may still appear to be in peak physical shape, yet they could potentially begin to encounter a host of psychological and cognitive problems. Failure to diagnose TBI threatens warfighters' health on many fronts. First, undiagnosed warfighters may not receive follow-up observation to look for signs of deteriorat ...
#  'backgroundTextHtml': 'CROSS-REFERENCE TO RELATED APPLICATION\n(1) This application claims priority to U.S. provisional patent application No. 61/680,888, filed Aug. 8, 2012.',
#  'subHeadingM0Html': None,
#  'subHeadingM1Html': None,
#  'subHeadingM2Html': None,
#  'subHeadingM3Html': None,
#  'subHeadingM4Html': None,
#  'subHeadingM5Html': None,
#  'subHeadingM6Html': None,
#  'usClassIssued': None,
#  'issuedUsDigestRefClassifi': None,
#  'datePublYear': '2023',
#  'applicationYear': '2013',
#  'pfDerwentWeekYear': None,
#  'pfApplicationYear': None,
#  'pfPublYear': None,
#  'reissueApplNumber': None,
#  'abstractHeader': None,
#  'abstractedPublicationDerwent': None,
#  'affidavit130BFlag': None,
#  'affidavit130BText': None,
#  'applicantGroup': ['Bibian; Stéphane Cleveland Heights OH US',
#   'Zikov; Tatjana Cleveland Heights OH US',
#   'Barua; Sankar Stow OH US'],
#  'applicantHeader': None,
#  'applicationFilingDateInt': 20130808,
#  'applicationFilingDateIntKwicHits': None,
#  'applicationRefFilingType': 'utility',
#  'applicationReferenceGroup': None,
#  'applicationSeriesAndNumber': '13962565',
#  'applicationSeriesCode': '13',
#  'assignee1': None,
#  'assigneeDescriptiveText': None,
#  'patentAssigneeTerms': None,
#  'associateAttorneyName': None,
#  'attorneyName': ['Kolkowski; Brian'],
#  'biologicalDepositInformation': None,
#  'applicationType': None,
#  'unlinkedDerwentRegistryNumber': None,
#  'unlinkedRingIndexNumbersRarerFragments': None,
#  'claimStatement': 'What is claimed is:',
#  'claimsTextAmended': None,
#  'continuedProsecutionAppl': None,
#  'cpcAdditionalLong': None,
#  'cpcCisClassificationOrig': None,
#  'cpcCombinationClassificationOrig': None,
#  'cpcInventive': ['A61M5/1723 20130101', 'A61B5/369 20210101'],
#  'cpcInventiveCurrentDateKwicHits': None,
#  'cpcAdditional': ['A61M2005/14296 20130101', 'A61M2005/14208 20130101'],
#  'cpcAdditionalCurrentDateKwicHits': None,
#  'cpcOrigClassificationGroup': ['A A61M A61M5/1723 20130101 F I 20230131 US',
#   'A A61B A61B5/369 20210101 L I 20230131 US',
#   'A A61M A61M2005/14208 20130101 L A 20230131 US',
#   'A A61M A61M2005/14296 20130101 L A 20230131 US'],
#  'curIntlPatentClassificationGroup': None,
#  'curUsClassificationUsPrimaryClass': None,
#  'curUsClassificationUsSecondaryClass': None,
#  'customerNumber': None,
#  'depositAccessionNumber': None,
#  'depositDescription': None,
#  'derwentClassAlpha': None,
#  'designatedstatesRouteGroup': None,
#  'docAccessionNumber': None,
#  'drawingDescription': None,
#  'editionField': None,
#  'exchangeWeek': None,
#  'exemplaryClaimNumber': ['1'],
#  'familyIdentifierOrig': None,
#  'fieldOfSearchCpcClassification': ['A61M 21/00',
#   'A61M 19/00',
#   'A61M 5/1723',
#   'A61M 2005/1405',
#   'A61M 2005/14208',
#   'A61M 2005/14296',
#   'G06Q 10/06',
#   'A61B 5/0476',
#   'A61B 5/0478',
#   'A61B 5/048',
#   'A61B 5/4821',
#   'G06F 19/3468'],
#  'fieldOfSearchCpcMainClass': ['A61M',
#   'A61M',
#   'A61M',
#   'A61M',
#   'A61M',
#   'A61M',
#   'G06Q',
#   'A61B',
#   'A61B',
#   'A61B',
#   'A61B',
#   'G06F'],
#  'fieldOfSearchIpcMainClass': None,
#  'fieldOfSearchIpcMainClassSubclass': None,
#  'fieldOfSearchSubclasses': None,
#  'foreignRefGroup': None,
#  'foreignRefPubDate': None,
#  'foreignRefPubDateKwicHits': None,
#  'foreignRefCitationClassification': None,
#  'foreignRefPatentNumber': None,
#  'foreignRefCitationCpc': None,
#  'foreignRefCountryCode': None,
#  'iceXmlIndicator': 'Y',
#  'internationalClassificationHeader': None,
#  'internationalClassificationInformationalGroup': None,
#  'intlPubClassificationGroup': ['20060101 A A61B A61B5/0476 F I B US H 20230131',
#   '20060101 A A61M A61M5/172 L I B US H 20230131',
#   '20210101 A A61B A61B5/369 L I B US H 20230131',
#   '20060101 A A61M A61M5/142 L N B US H 20230131'],
#  'intlPubClassificationNonInvention': ['A61M5/142 20060101 A61M005/142'],
#  'inventorCitizenship': None,
#  'inventorCorrection': None,
#  'inventorDeceased': None,
#  'inventorStreetAddress': None,
#  'inventorText': None,
#  'jpoFiClassification': None,
#  'legalRepresentativeCity': None,
#  'legalRepresentativeCountry': '[]',
#  'legalRepresentativeName': None,
#  'legalRepresentativePostcode': None,
#  'legalRepresentativeState': None,
#  'legalRepresentativeStreetAddress': None,
#  'legalRepresentativeText': None,
#  'messengerDocsFlag': None,
#  'newRecordPatentDerwent': None,
#  'numberOfClaims': '20',
#  'numberOfDrawingSheets': '56',
#  'numberOfFigures': '60',
#  'numberOfPagesInSpecification': None,
#  'numberOfPagesOfSpecification': None,
#  'objectContents': None,
#  'objectDescription': None,
#  'parentDocCountry': None,
#  'parentGrantDocCountry': None,
#  'patentBibliographicHeader': None,
#  'pctOrRegionalPublishingSerial': None,
#  'pfDerwentWeekNum': None,
#  'principalAttorneyName': ['Kolkowski; Brian'],
#  'priorityApplicationCountry': None,
#  'priorityClaimsCountry': None,
#  'priorityNumberDerived': None,
#  'publicationIssueNumber': None,
#  'refCitedPatentDocNumber': None,
#  'refCitedPatentDocDate': None,
#  'refCitedPatentDocKindCode': None,
#  'referenceCitedCode': None,
#  'referenceCitedGroup': None,
#  'referenceCitedSearchPhase': None,
#  'referenceCitedText': None,
#  'registrationNumber': None,
#  'reissueApplCountry': None,
#  'reissueParentKind': None,
#  'reissueParentNumber': None,
#  'reissueParentPubCountry': None,
#  'reissuePatentGroup': None,
#  'reissuePatentParentStatus': None,
#  'reissuedPatentApplCountry': None,
#  'reissuedPatentApplKind': None,
#  'reissuedPatentApplNumber': None,
#  'relatedApplChildPatentCountry': None,
#  'relatedApplChildPatentName': None,
#  'relatedApplChildPatentNumber': None,
#  'relatedApplCountryCode': None,
#  'relatedApplParentGrantPatentKind': None,
#  'relatedApplParentGrantPatentName': None,
#  'relatedApplParentPatentKind': None,
#  'relatedApplParentPatentName': None,
#  'relatedApplParentPctDoc': None,
#  'relatedApplParentStatusCode': None,
#  'relatedApplPatentNumber': None,
#  'relatedApplRelatedPub': None,
#  'relatedApplTypeOfCorrection': None,
#  'rule47Flag': None,
#  'selectedDrawingCharacter': None,
#  'selectedDrawingFigure': None,
#  'statutoryInventionText': None,
#  'termOfExtension': '214',
#  'termOfPatentGrant': None,
#  'titleTermsData': None,
#  'additionalIndexingTerm': None,
#  'applicationYearSearch': '2013',
#  'pfApplicationYearSearch': None,
#  'assigneeCountry': ['US'],
#  'certOfCorrectionFlag': None,
#  'citedPatentLiteratureAddressInformation': None,
#  'citedPatentLiteratureClassificationIpc': None,
#  'citedPatentLiteratureOrganizationName': None,
#  'citedPatentLiteratureRefNumber': None,
#  'crossReferenceNumber': None,
#  'country': 'US',
#  'cpiManualCodes': None,
#  'cpiSecondaryAccessionNumber': None,
#  'curIntlPatentAllClassificationLong': None,
#  'currentUsOriginalClassificationLong': None,
#  'datePublSearch': '2023-01-31T00:00:00.000+00:00',
#  'datePublYearSearch': '2023',
#  'epiManualCodes': None,
#  'fieldOfSearchMainClassNational': None,
#  'inventorCountry': ['US', 'US', 'US'],
#  'ipcAllMainClassification': ['A61M', 'A61B'],
#  'issuedUsClassificationFull': None,
#  'issuedUsDigestRefClassification': None,
#  'jpoFiCurrentAdditionalClassification': None,
#  'jpoFiCurrentInventiveClassification': None,
#  'legalFirmName': None,
#  'locarnoMainClassification': None,
#  'nonCpiSecondaryAccessionNumber': None,
#  'objectId': None,
#  'otherRefPub': None,
#  'pageNumber': None,
#  'patentAssigneeCode': None,
#  'patentAssigneeNameTotal': None,
#  'patentFamilyDate': None,
#  'patentFamilyDocNumber': None,
#  'patentFamilyKind': None,
#  'patentFamilyKindCode': None,
#  'patentFamilyLanguage': None,
#  'patentFamilyName': None,
#  'patentNumberOfLocalApplication': None,
#  'pct102eDate': None,
#  'pct371c124Date': None,
#  'pct371c124DateKwicHits': None,
#  'pctFilingDate': None,
#  'pctFilingDateKwicHits': None,
#  'pctFilingDocCountryCode': None,
#  'pctFilingKind': None,
#  'pctFilingNumber': None,
#  'pctName': None,
#  'pctOrRegionalPublishingCountry': None,
#  'pctOrRegionalPublishingKind': None,
#  'pctOrRegionalPublishingName': None,
#  'pctOrRegionalPublishingText': None,
#  'pctPubDate': None,
#  'pctPubDateKwicHits': None,
#  'pctPubDocIdentifier': None,
#  'pctPubNumber': None,
#  'pfApplicationDateSearch': None,
#  'pfApplicationType': None,
#  'pfDerwentWeekDate': None,
#  'pfPublDateSearch': None,
#  'pfPublDateSearchKwicHits': None,
#  'pfPublYearSearch': None,
#  'polymerIndexingCodes': None,
#  'polymerMultipunchCodeRecordNumber': None,
#  'polymerMultipunchCodes': None,
#  'priorPublishedDocCountryCode': None,
#  'priorPublishedDocDate': None,
#  'priorPublishedDocDateKwicHits': None,
#  'priorPublishedDocIdentifier': None,
#  'priorPublishedDocKindCode': None,
#  'priorPublishedDocNumber': None,
#  'priorityApplYear': None,
#  'priorityApplicationDate': None,
#  'priorityClaimsDateSearch': None,
#  'priorityClaimsDocNumber': None,
#  'priorityPatentDid': None,
#  'priorityPatentNumber': None,
#  'ptabCertFlag': None,
#  'pubRefCountryCode': None,
#  'pubRefDocNumber': '11565042',
#  'pubRefDocNumber1': '11565042',
#  'publicationData': None,
#  'recordPatentNumber': None,
#  'reexaminationFlag': None,
#  'refCitedOthers': None,
#  'refCitedPatentDocCountryCode': None,
#  'refCitedPatentDocName': None,
#  'refCitedPatentRelevantPassage': None,
#  'reissueParentIssueDate': None,
#  'reissuedPatentApplFilingDate': None,
#  'relatedAccessionNumbers': None,
#  'relatedApplChildPatentDate': None,
#  'relatedApplFilingDateKwicHits': None,
#  'relatedApplNumber': ['61680888'],
#  'relatedApplPatentIssueDate': None,
#  'relatedApplPatentIssueDateKwicHits': None,
#  'relatedDocumentKindCode': None,
#  'securityLegend': None,
#  'sequenceCwu': None,
#  'sequenceListNewRules': None,
#  'sequenceListOldRules': None,
#  'sequencesListText': None,
#  'standardTitleTerms': None,
#  'supplementalExaminationFlag': None,
#  'usBotanicLatinName': None,
#  'usBotanicVariety': None,
#  'usRefClassification': ['128/920',
#   '700/200',
#   '128/203.12',
#   '128/204.23',
#   '600/595',
#   '604/65',
#   '604/66',
#   '235/375',
#   '600/544',
#   '604/67'],
#  'usRefCpcClassification': ['A61B 5/14532',
#   'B29C 45/766',
#   'A61M 16/0051',
#   'A61B 5/4821',
#   'A61B 5/369',
#   'A61B 5/4839',
#   'A61M 5/142',
#   'A61M 5/16827',
#   'A61B 5/4821',
#   'A61M 5/1689'],
#  'usRefGroup': ['US 5741211 A Renirie 19980400 cited by examiner A61B 5/14532 128/920',
#   'US 5786999 A Spahr 19980700 cited by examiner B29C 45/766 700/200',
#   'US 7438072 B2 Izuchukwu 20081000 cited by examiner A61M 16/0051 128/203.12',
#   'US 20020017296 A1 Hickle 20020200 cited by examiner A61B 5/4821 128/204.23',
#   'US 20040193068 A1 Burton 20040900 cited by examiner A61B 5/369 600/595',
#   'US 20060009733 A1 Martin 20060100 cited by examiner A61B 5/4839 604/65',
#   'US 20060009734 A1 Martin 20060100 cited by examiner A61M 5/142 604/66',
#   'US 20110021978 A1 Martin 20110100 cited by examiner A61M 5/16827 235/375',
#   'US 20110130675 A1 Bibian 20110600 cited by examiner A61B 5/4821 600/544',
#   'US 20120095433 A1 Hungerford 20120400 cited by examiner A61M 5/1689 604/67'],
#  'usRefIssueDate': ['19980400',
#   '19980700',
#   '20081000',
#   '20020200',
#   '20040900',
#   '20060100',
#   '20060100',
#   '20110100',
#   '20110600',
#   '20120400'],
#  'usRefIssueDateKwicHits': ['19980400',
#   '19980700',
#   '20081000',
#   '20020200',
#   '20040900',
#   '20060100',
#   '20060100',
#   '20110100',
#   '20110600',
#   '20120400'],
#  'usRefPatenteeName': ['Renirie',
#   'Spahr',
#   'Izuchukwu',
#   'Hickle',
#   'Burton',
#   'Martin',
#   'Martin',
#   'Martin',
#   'Bibian',
#   'Hungerford'],
#  'volumeNumber': None,
#  'correspondenceNameAddress': None,
#  'correspondenceAddressCustomerNumber': None,
#  'ibmtdbAccessionNumber': None,
#  'inventorsName': ['Bibian; Stéphane', 'Zikov; Tatjana', 'Barua; Sankar'],
#  'applicationKindCode': 'B1',
#  'inventorNameDerived': None,
#  'intlPubClassificationClass': ['A61B', 'A61M', 'A61B', 'A61M'],
#  'issuedUsOrigClassification': None,
#  'curCpcSubclassFull': ['A61M', 'A61M', 'A61B'],
#  'cpcCurAdditionalClass': ['A61M', 'A61M'],
#  'cpcCurInventiveClass': ['A61M', 'A61B'],
#  'cpcCurClassificationGroup': ['A A61M A61M5/1723 20130101 F I B H 20230131 US',
#   'A A61M A61M2005/14296 20130101 L A B H 20230131 US',
#   'A A61M A61M2005/14208 20130101 L A B H 20230131 US',
#   'A A61B A61B5/369 20210101 L I B C 20230131 US'],
#  'curCpcClassificationFull': ['A61M2005/14296 20130101',
#   'A61M5/1723 20130101',
#   'A61B5/369 20210101',
#   'A61M2005/14208 20130101'],
#  'cpcCombinationClassificationCur': None,
#  'cpcCombinationTallyCur': None,
#  'intlFurtherClassification': None,
#  'currentUsPatentClass': ['1'],
#  'idWithoutSolrPartition': 'US-US-11565042',
#  'curIntlPatentClassifictionPrimaryDateKwicHits': None,
#  'curIntlPatentClssifSecHlights': None,
#  'internationalClassificationInfom': None,
#  'cpcOrigInventvClssifHlghts': ['A61M5/1723 20130101', 'A61B5/369 20210101'],
#  'descriptionStart': 58,
#  'descriptionEnd': 84,
#  'publicationReferenceDocumentNumberOne': '11565042'}

# %%
# citation collection에 저장된 document 출력
collection = db["citations"]
collection.find_one()
# Out:
# {'_id': ObjectId('64097a1b01e2bf0d26e37fd8'),
#  'cited': '5741211',
#  'citing': '11565042'}

# %%
# 'country' 컬럼이 'US'인 특허 추출
for i, doc in enumerate(db.USPAT.find({'country': 'US'}, {'guid': 1, 'country': 1, '_id': 0})):
    print(doc)
    if i > 10: break
        
# [SQL]
# SELECT guid, country
# FROM USPAT
# WHERE country = 'US';
# Out:
# {'guid': 'US-11565042-B1', 'country': 'US'}
# {'guid': 'US-11565025-B1', 'country': 'US'}
# {'guid': 'US-11565470-B1', 'country': 'US'}
# {'guid': 'US-11568442-B1', 'country': 'US'}
# {'guid': 'US-11568982-B1', 'country': 'US'}
# {'guid': 'US-11568388-B1', 'country': 'US'}
# {'guid': 'US-11568389-B1', 'country': 'US'}
# {'guid': 'US-11568038-B1', 'country': 'US'}
# {'guid': 'US-11568446-B1', 'country': 'US'}
# {'guid': 'US-11568377-B1', 'country': 'US'}
# {'guid': 'US-11568301-B1', 'country': 'US'}
# {'guid': 'US-11568863-B1', 'country': 'US'}

# %%
# IPC에 G06F가 포함된 특허 추출
for i, doc in enumerate(db.USPAT.find({'ipcCodeFlattened': {"$regex": 'G06F'}}, 
                                      {'ipcCodeFlattened': 1, 'inventionTitle': 1, '_id': 0}).limit(10)):
    print(doc,"\n")
    
# [SQL]
# SELECT inventionTitle, ipcCodeFlattened
# FROM USPAT
# WHERE ipcCodeFlattened LIKE '%G06F%';
# Out:
# {'inventionTitle': 'Machine learning in resource-constrained environments', 'ipcCodeFlattened': 'G06N20/00;G06F8/65'}
#
# {'inventionTitle': 'Applied artificial intelligence technology for narrative generation based on explanation communication goals', 'ipcCodeFlattened': 'G06F40/30;G06F40/295'}
#
# {'inventionTitle': 'Semi-structured data machine learning', 'ipcCodeFlattened': 'G06N20/00;G06F16/835'}
#
# {'inventionTitle': 'Tree-based format for data storage', 'ipcCodeFlattened': 'G06F16/22;G06F16/28'}
#
# {'inventionTitle': 'Virtual storage interface', 'ipcCodeFlattened': 'G06F16/188;G06Q40/00'}
#
# {'inventionTitle': 'Copying buckets from a remote shared storage system to memory associated with a search node for query execution', 'ipcCodeFlattened': 'G06F16/901;G06F16/2458'}
#
# {'inventionTitle': 'Event-based debug, trace, and profile in device with data processing engine array', 'ipcCodeFlattened': 'G06F13/10;G06F13/16'}
#
# {'inventionTitle': 'Blockchain network based on machine learning-based proof of work', 'ipcCodeFlattened': 'G06N20/00;G06N3/00;G06F16/23'}
#
# {'inventionTitle': 'Placement and pricing of part marks in computer-modeled structures', 'ipcCodeFlattened': 'G06F30/17;G06Q30/02'}
#
# {'inventionTitle': 'Risk-based scheduling for credential rotation', 'ipcCodeFlattened': 'G06F21/45;G06F21/46'}

# %%
pipeline = list()
pipeline.append({'$limit': 100000})
pipeline.append({'$out': 'citations_mini'})
results = db.citations.aggregate(pipeline)

# %%
pipeline = list()
pipeline.append({'$limit': 50000})
pipeline.append({'$out': 'USPAT_mini'})
results = db.USPAT.aggregate(pipeline)

# %%
# 특허 문서 수가 100개 이상인 특허 클래스 조합별 특허 문서 수와 평균 청구항 수 추출
pipeline = list()
pipeline.append({'$group': {'_id': '$ipcAllMainClassification', 'patent_Count': {'$sum': 1}, 
                            'average_Claims': {'$avg': {'$toDecimal': '$numberOfClaims'}}}})
pipeline.append({'$addFields': {'average_Claims': {'$round': ['$average_Claims', 2]}}})
pipeline.append({'$match': {'patent_Count': {'$gte': 100}}})
print(pipeline, "\n")

results = db.USPAT_mini.aggregate(pipeline)
for i, doc in enumerate(results):
    print(doc)
    if i > 10: break
        
# [SQL]
# SELECT ipcAllMainClassification, patent_Count, average_Claims
# FROM
# (
#    SELECT ipcAllMainClassification, COUNT(*) AS patent_Count, AVG(numberofClaims) AS average_Claims
#    FROM USPAT
#    GROUP BY ipcAllMainClassification
# )
# WHERE patent_Count >= 100;
# Out:
# [{'$group': {'_id': '$ipcAllMainClassification', 'patent_Count': {'$sum': 1}, 'average_Claims': {'$avg': {'$toDecimal': '$numberOfClaims'}}}}, {'$addFields': {'average_Claims': {'$round': ['$average_Claims', 2]}}}, {'$match': {'patent_Count': {'$gte': 100}}}]
#
# {'_id': ['G06Q', 'H04L', 'G06F'], 'patent_Count': 178, 'average_Claims': Decimal128('19.25')}
# {'_id': ['H04L', 'H04W'], 'patent_Count': 983, 'average_Claims': Decimal128('18.55')}
# {'_id': ['H04L', 'H04B'], 'patent_Count': 138, 'average_Claims': Decimal128('19.51')}
# {'_id': ['H04L', 'G06F'], 'patent_Count': 1153, 'average_Claims': Decimal128('18.66')}
# {'_id': ['G11C', 'H01L'], 'patent_Count': 176, 'average_Claims': Decimal128('17.53')}
# {'_id': ['H04N', 'G06F'], 'patent_Count': 157, 'average_Claims': Decimal128('16.24')}
# {'_id': ['H01M'], 'patent_Count': 586, 'average_Claims': Decimal128('13.31')}
# {'_id': ['G03G'], 'patent_Count': 129, 'average_Claims': Decimal128('15.62')}
# {'_id': ['G02B'], 'patent_Count': 176, 'average_Claims': Decimal128('16.59')}
# {'_id': ['G06N', 'G06F'], 'patent_Count': 410, 'average_Claims': Decimal128('18.79')}
# {'_id': ['G06N'], 'patent_Count': 122, 'average_Claims': Decimal128('18.34')}
# {'_id': ['E21B'], 'patent_Count': 259, 'average_Claims': Decimal128('17.15')}
